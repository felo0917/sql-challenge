# %%
#Dependencies
import pandas as pd
from config import password
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %%
from sqlalchemy import create_engine
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/employee_db')

connection = engine.connect()

# %%
employees_df = pd.read_sql("SELECT * FROM employees", connection)
employees_df
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date
# 0       1990-04-28
# 1       1991-09-07
# 2       1992-03-21
# 3       1987-11-26
# 4       1991-01-18
# ...            ...
# ...

# %%
salaries_df = pd.read_sql("SELECT * FROM salaries", connection)
salaries_df.head()
# Out:
#    emp_no  salaries
# 0   10001     60117
# 1   10002     65828
# 2   10003     40006
# 3   10004     40054
# 4   10005     78228

# %%
title_df = pd.read_sql("SELECT * FROM titles", connection)
title_df.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
employee_salary_df=employees_data.merge(salaries_df, on='emp_no')
employee_salary_df.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date  \
# 0  473302        s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053        e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444        e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786        s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238        e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18
#
#    salaries
# 0     40000
# 1     53422
# 2     48973
# 3     40000
# 4     40000

# %%
final_df=employee_salary_df.merge(title_df, left_on= 'emp_title_id', right_on='title_id') 
final_df.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name   last_name sex   hire_date  \
# 0  473302        s0001  1953-07-25    Hideyuki    Zallocco   M  1990-04-28
# 1  421786        s0001  1957-09-28       Xiong    Verhoeff   M  1987-11-26
# 2  273487        s0001  1957-04-14   Christoph     Parfitt   M  1991-06-28
# 3  246449        s0001  1958-03-23       Subbu  Bultermann   F  1988-03-25
# 4   48085        s0001  1964-01-19  Venkatesan        Gilg   M  1993-06-28
#
#    salaries title_id  title
# 0     40000    s0001  Staff
# 1     40000    s0001  Staff
# 2     56087    s0001  Staff
# 3     87084    s0001  Staff
# 4     63016    s0001  Staff

# %%
#Create a histogram to visualize the most common salary ranges for employees.
sns.distplot(final_df['salaries'], kde=False, color='blue', bins=15, label= 'Salary')
plt.title('Salary ranges for employees', fontsize=16)
plt.legend(prop={'size': 12})
plt.xlabel('Salaries', fontsize=14)
plt.ylabel('# of employees', fontsize=14)
# Out:
# Text(0, 0.5, '# of employees')

# %%
#Create a bar chart of average salary by title.
from numpy import mean
sns.set(style="whitegrid")
sns.barplot(data=final_df, x = 'title', y = 'salaries')
plt.title('Average Salary by Title', fontsize=16)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text major ticklabel objects>)
